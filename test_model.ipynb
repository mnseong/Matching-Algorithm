# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary

from models.ShoelaceNet import ShoelaceNet
# from transformers import ConvNextConfig, ConvNextModel
from models.convnextv2 import convnextv2

# %%
#net = SwapNet().eval().to('cuda')

# %%
#summary(net, (3, 224, 224))

# %%
# net2 = convnextv2
# convnextv2.convnextv2_base().eval().to('cuda')

# %%
# convnextv2_base = nn.Sequential(*list(net2.convnextv2_base().children())[:-1])

# %%
# convnextv2_base

# %%
# model.classifier = nn.Sequential(*list(model.classifier.children())[:-3])

# %%
class Extractor_ConvNext_V2(nn.Module):
    # self.convnextv2 = nn.Sequential(*list(convnextv2.convnextv2_base().children())[:-1])
    
    def __init__(self):
        super().__init__()
        self.convnextv2 = nn.Sequential(*list(convnextv2.convnextv2_base().children())[:-1])

    def forward(self, x):
        # print(x.shape)
        x = self.convnextv2(x)
        # print(x.shape)
        return x

# %%
convnext_model = Extractor_ConvNext_V2()
convnext_model
# Out:
# Extractor_ConvNext_V2(
#   (convnextv2): Sequential(
#     (0): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#         (1): LayerNorm()
#       )
#       (1): Sequential(
#         (0): LayerNorm()
#         (1): Conv2d(128, 256, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (2): Sequential(
#         (0): LayerNorm()
#         (1): Conv2d(256, 512, kernel_size=(2, 2), stride=(2, 2))
#       )
#       (3): Sequential(
#         (0): LayerNorm()
#         (1): Conv2d(512, 1024, kernel_size=(2, 2), stride=(2, 2))
#       )
#     )
#     (1): ModuleList(
#       (0): Sequential(
#         (0): Block(
#           (dwconv): Conv2d(128, 128, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=128)
#           (norm): LayerNorm()
#           (pwconv1): Linear(in_features=128, out_features=512, bias=True)
#           (act): GELU(approximate='none')
#           (grn): GRN()
# ...

# %%
convnext_model((3, 224, 224))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 convnext_model((3, 224, 224))
#
# File ~/.pyenv/versions/Matching-Algorithm/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[28], line 10, in Extractor_ConvNext_V2.forward(self, x)
# ...

# %%
summary(convnext_model, (3, 224, 224))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 summary(convnext_model, (3, 224, 224))
#
# File ~/.pyenv/versions/Matching-Algorithm/lib/python3.11/site-packages/torchsummary/torchsummary.py:72, in summary(model, input_size, batch_size, device)
#      68 model.apply(register_hook)
#      70 # make a forward pass
#      71 # print(x.shape)
# ---> 72 model(*x)
#      74 # remove these hooks
#      75 for h in hooks:
#
# File ~/.pyenv/versions/Matching-Algorithm/lib/python3.11/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
# ...
